# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("kidney_disease.csv")

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
len(df)
# Out:
# 400

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    str
#  7   pc              335 non-null    str
#  8   pcc             396 non-null    str
#  9   ba              396 non-null    str
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    str
# ...

# %%
sns.boxplot(df['bu'])
# Out:
# <Axes: ylabel='bu'>

# %%
# appet             1
# pe                1
# ane  
df['classification'].unique()
# Out:
# <StringArray>
# ['ckd', 'notckd']
# Length: 2, dtype: str

# %%
df['classification'].value_counts()
# Out:
# classification
# ckd       250
# notckd    150
# Name: count, dtype: int64

# %%
# df['wc'] = df['wc'].str.replace('\t', '', regex=True)
# df['wc'] = df['wc'].replace('?', 0)
# df['wc'] = df['wc'].fillna(0).astype(float)
# df['wc'] = df['wc'].replace(0, df['wc'].mean(), regex=True)


# df['rc'] = df['rc'].str.replace('\t', '', regex=True)
# df['rc'] = df['rc'].replace('?', 0)
# df['rc'] = df['rc'].fillna(0).astype(float)
# df['rc'] = df['rc'].replace(0, df['rc'].mean(), regex=True)


# df['pcv'] = df['pcv'].str.replace('\t', '', regex=True)
# df['pcv'] = df['pcv'].replace('?', 0)
# df['pcv'] = df['pcv'].fillna(0).astype(float)
# df['pcv'] = df['pcv'].replace(0, df['pcv'].mean(), regex=True)


# df['pot'] = df['pot'].fillna(df['pot'].mean())


# df['sod'] = df['sod'].fillna(df['sod'].median())


# df['bgr'] = df['bgr'].fillna(df['bgr'].median())

# df['bu'] = df['bu'].fillna(df['bu'].median())
# df['sc'] = df['sc'].fillna(df['sc'].median())

# df['dm'] = df['dm'].str.strip()
# df['cad'] = df['cad'].str.strip()
# df['classification'] = df['classification'].str.strip()

# %%
df["rbc"] = df["rbc"].fillna("normal")
df["pc"] = df["pc"].fillna("normal")
df["pcc"] = df["pcc"].fillna("notpresent")
df["ba"] = df["ba"].fillna("notpresent")

df["htn"] = df["htn"].fillna("no")

df["dm"] = df["dm"].fillna("no")

df["cad"] = df["cad"].fillna("no")
df["ane"] = df["ane"].fillna("no")
df["pe"] = df["pe"].fillna("no")
df["appet"] = df["appet"].fillna("good")

# %%
df['bp'] = df['bp'].fillna(df['bp'].median())
df['sg'] = df['sg'].fillna(df['sg'].median())
df['age'] = df['age'].fillna(df['age'].mean())
df['al'] = df['al'].fillna(df['al'].mean())
df['su'] = df['su'].fillna(df['su'].mean())
df['hemo'] = df['hemo'].fillna(df['hemo'].mean())

# %%
df.isnull().sum()
# Out:
# id                0
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# df.to_csv("cleaned_kidney_disease.csv")

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0  normal    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0  normal    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...   pcv      wc       rc  htn   dm  cad  appet   pe  ane classification
# 0  ...  44.0  7800.0  5.20000  yes  yes   no   good   no   no            ckd
# 1  ...  38.0  6000.0  3.16575   no   no   no   good   no   no            ckd
# 2  ...  31.0  7500.0  3.16575   no  yes   no   poor   no  yes            ckd
# 3  ...  32.0  6700.0  3.90000  yes   no   no   poor  yes  yes            ckd
# 4  ...  35.0  7300.0  4.60000   no   no   no   good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
col = list(df.columns)

# %%
for i in col:
    print(f"{i} ----> {df[i].dtype}")
# Out:
# id ----> int64
# age ----> float64
# bp ----> float64
# sg ----> float64
# al ----> float64
# su ----> float64
# rbc ----> str
# pc ----> str
# pcc ----> str
# ba ----> str
# bgr ----> float64
# bu ----> float64
# sc ----> float64
# sod ----> float64
# pot ----> float64
# hemo ----> float64
# pcv ----> float64
# wc ----> float64
# rc ----> float64
# htn ----> str
# dm ----> str
# cad ----> str
# appet ----> str
# pe ----> str
# ane ----> str
# classification ----> str

# %%
str_col = []
float_col = []
for i in col:
    if df[i].dtype =='str':
        str_col.append(i)
    elif df[i].dtype =='float':
        float_col.append(i)

# %%
float_col
# Out:
# ['age',
#  'bp',
#  'sg',
#  'al',
#  'su',
#  'bgr',
#  'bu',
#  'sc',
#  'sod',
#  'pot',
#  'hemo',
#  'pcv',
#  'wc',
#  'rc']

# %%
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2

# %%
a
# Out:
# [<StringArray>
#  ['normal', 'abnormal']
#  Length: 2, dtype: str,
#  <StringArray>
#  ['normal', 'abnormal']
#  Length: 2, dtype: str,
#  <StringArray>
#  ['notpresent', 'present']
#  Length: 2, dtype: str,
#  <StringArray>
#  ['notpresent', 'present']
#  Length: 2, dtype: str,
#  <StringArray>
#  ['yes', 'no']
#  Length: 2, dtype: str,
#  <StringArray>
#  ['yes', 'no']
#  Length: 2, dtype: str,
#  <StringArray>
#  ['no', 'yes']
#  Length: 2, dtype: str,
#  <StringArray>
#  ['good', 'poor']
#  Length: 2, dtype: str,
#  <StringArray>
#  ['no', 'yes']
#  Length: 2, dtype: str,
#  <StringArray>
#  ['no', 'yes']
#  Length: 2, dtype: str,
#  <StringArray>
#  ['ckd', 'notckd']
#  Length: 2, dtype: str]
